# %%
import pandas as pd
import csv
import os
import numpy as py

# %%
file_path = "./battles.csv"
battles_df = pd.read_csv(file_path)
battles_df = battles_df.reset_index(drop = True)
battles_df
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battles_dict = battles_df.to_dict('records')
print(battles_dict)

battles_dict
# Out:
# [{'name': 'Battle of the Golden Tooth', 'year': 298, 'battle_number': 1, 'attacker_king': 'Joffrey/Tommen Baratheon', 'defender_king': 'Robb Stark', 'attacker_1': 'Lannister', 'attacker_2': nan, 'attacker_3': nan, 'attacker_4': nan, 'defender_1': 'Tully', 'defender_2': nan, 'defender_3': nan, 'defender_4': nan, 'attacker_outcome': 'win', 'battle_type': 'pitched battle', 'major_death': True, 'major_capture': False, 'attacker_size': 15000.0, 'defender_size': 4000.0, 'attacker_commander': 'Jaime Lannister', 'defender_commander': 'Clement Piper, Vance', 'summer': True, 'location': 'Golden Tooth', 'region': 'The Westerlands', 'note': nan}, {'name': "Battle at the Mummer's Ford", 'year': 298, 'battle_number': 2, 'attacker_king': 'Joffrey/Tommen Baratheon', 'defender_king': 'Robb Stark', 'attacker_1': 'Lannister', 'attacker_2': nan, 'attacker_3': nan, 'attacker_4': nan, 'defender_1': 'Baratheon', 'defender_2': nan, 'defender_3': nan, 'defender_4': nan, 'attacker_outcome': 'win', 'battle_typ
# ...
