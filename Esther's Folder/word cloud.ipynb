# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-edb97eff82f3> in <module>
#       1 import pandas as pd
# ----> 2 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Load in csv
script_df = pd.read_csv("../data/scripts.csv")
script_df.head()
# Out:
#   Release Date    Season    Episode     Episode Title          Name  \
# 0   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 1   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 2   2011-04-17  Season 1  Episode 1  Winter is Coming  waymar royce
# 3   2011-04-17  Season 1  Episode 1  Winter is Coming          will
# 4   2011-04-17  Season 1  Episode 1  Winter is Coming         gared
#
#                                             Sentence
# 0  What do you expect? They're savages. One lot s...
# 1  I've never seen wildlings do a thing like this...
# 2                             How close did you get?
# 3                            Close as any man would.
# 4                   We should head back to the wall.

# %%
script_df2 = script_df.replace(' ', '_', regex=True)

# %%
names = script_df2['Name'].to_numpy()
namestring = ""
for name in names:
    namestring = namestring + str(name) + " "
print(namestring)
# names = " ".join(str(names))
# print(names)
# Out:
# waymar_royce will waymar_royce will gared royce gared royce will royce royce will gared royce gared jon_snow jon_snow septa_mordane sansa_stark septa_mordane eddard_stark jon_snow robb_stark jonrobb cassel eddard_stark catelyn_stark eddard_stark cassel eddard_stark catelyn_stark eddard_stark robb_stark will will eddard_stark will eddard_stark jon_snow eddard_stark jon_snow eddard_stark jon_snow eddard_stark bran_stark eddard_stark bran_stark eddard_stark bran_stark eddard_stark bran_stark eddard_stark jon_snow theon_greyjoy eddard_stark theon_greyjoy eddard_stark eddard_stark robb_stark jon_snow jon_snow bran_stark cassel eddard_stark theon_greyjoy bran_stark robb_stark theon_greyjoy bran_stark eddard_stark jon_snow eddard_stark bran_stark jon_snow robb_stark theon_greyjoy jaime_lannister cersei_lannister jaime_lannister cersei_lannister jaime_lannister cersei_lannister jaime_lannister cersei_lannister jaime_lannister catelyn_stark eddard_stark catelyn_stark eddard_stark catelyn_star
# ...

# %%
# Word cloun to see more common ingredients:
#names=script2_df['Name']

print("Characters with the Most Lines")

wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    collocations=False,
    stopwords = STOPWORDS).generate(namestring)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.savefig("../Esther's Folder/scriptlines.png")
plt.show()
# Out:
# Characters with the Most Lines
