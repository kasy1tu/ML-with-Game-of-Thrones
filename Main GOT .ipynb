# %% [markdown]
# # Connect to SQL Database

# %%
import pandas as pd 
from sqlalchemy import create_engine
import plotly.graph_objects as go

# %%
# Load and read csv
csv_file = "./data/battles.csv"
got_battles = pd.read_csv(csv_file)

csv_file4 = "./data/scripts.csv"
got_scripts = pd.read_csv(csv_file4)
got_scripts_name = got_scripts[["Name"]]
got_scripts_name.columns = map(str.lower, got_scripts_name.columns)
got_scripts_name.to_csv("")

csv_file5 = "./data/ratings.csv"
got_ratings = pd.read_csv(csv_file5)
got_ratings.columns = map(str.lower, got_ratings.columns)
got_ratings_df = got_ratings.rename(columns ={
                            "season": "season",
                            "episode number": "episode_number", 
                            "number in season": "number_in_season",
                            "episode name": "episode_name",
                            "original air date":"original_air_date",
                            "us viewers (million)":"us_viewers_millions",
                            "runtime (mins)":"runtime_mins",
                            "imdb description":"imdb_description",
                            "imdb votes":"imdb_votes",
                            "imdb rating":"imdb_rating",
                            "notable death count":"notable_death_count"
                            })
got_cleaned = got_ratings_df[["season","episode_name", "director", "imdb_rating", "notable_death_count", "imdb_description"]]
got_cleaned = got_cleaned.sort_values(by="imdb_rating", ascending=False).head(10)
got_cleaned.to_csv("got_cleaned.csv", index=False)

csv_file6 = "./gabes-folder/backend/kings.csv"
kings_df = pd.read_csv(csv_file6)
kings_df.columns = map(str.lower, kings_df.columns)

csv_file7 = "./kasy-folder/backend/director.csv"
director_df = pd.read_csv(csv_file7)
director_df.columns = map(str.lower, director_df.columns)

csv_file8 = "./kasy-folder/backend/top_episodes.csv"
top_episodes_df = pd.read_csv(csv_file8)
top_episodes_df.columns = map(str.lower, top_episodes_df.columns)

# %%
got_ratings_df
# Out:
#     season  episode_number  number_in_season  \
# 0        1               1                 1
# 1        1               2                 2
# 2        1               3                 3
# 3        1               4                 4
# 4        1               5                 5
# ..     ...             ...               ...
# 68       8              69                 2
# 69       8              70                 3
# 70       8              71                 4
# 71       8              72                 5
# 72       8              73                 6
#
#                              episode_name                     director  \
# 0                        Winter Is Coming               Tim Van Patten
# 1                           The Kingsroad               Tim Van Patten
# 2                               Lord Snow                   Brian Kirk
# 3   Cripples, Bastards, and Broken Things                   Brian Kirk
# 4                   The Wolf and the Lion                   Brian Kirk
# ..                                    ...                          ...
# 68         A Knight of the Seven Kingdoms                 David Nutter
# 69                         The Long Night             Miguel Sapochnik
# 70                 The Last of the Starks                 David Nutter
# 71                              The Bells             Miguel Sapochnik
# 72                        The Iron Throne  David Benioff & D. B. Weiss
#
#                          writer original_air_date  us_viewers_millions  \
# 0   David Benioff & D. B. Weiss    April 17, 2011                 2.22
# 1   David Benioff & D. B. Weiss    April 24, 2011                 2.20
# 2   David Benioff & D. B. Weiss       May 1, 2011                 2.44
# 3                  Bryan Cogman       May 8, 2011                 2.45
# 4   David Benioff & D. B. Weiss      May 15, 2011                 2.58
# ..                          ...               ...                  ...
# 68                 Bryan Cogman    April 21, 2019                10.29
# 69  David Benioff & D. B. Weiss    April 28, 2019                12.02
# 70  David Benioff & D. B. Weiss       May 5, 2019                11.80
# 71  David Benioff & D. B. Weiss      May 12, 2019                12.40
# 72  David Benioff & D. B. Weiss      May 19, 2019                13.61
#
#     runtime_mins                                   imdb_description  \
# 0             62  Jon Arryn, the Hand of the King, is dead. King...
# 1             56  While Bran recovers from his fall, Ned takes o...
# 2             58  Lord Stark and his daughters arrive at King's ...
# 3             56  Eddard investigates Jon Arryn's murder. Jon be...
# 4             55  Catelyn has captured Tyrion and plans to bring...
# ..           ...                                                ...
# 68            58  Jaime faces judgment and Winterfell prepares f...
# 69            82  The Night King and his army have arrived at Wi...
# 70            78  The Battle of Winterfell is over and a new cha...
# 71            78  Forces have arrived at King's Landing for the ...
# 72            80  In the aftermath of the devastating attack on ...
#
#     imdb_votes  imdb_rating  notable_death_count
# 0        27685          9.0                    4
# 1        21256          8.8                    3
# 2        20090          8.7                    0
# 3        19123          8.8                    1
# 4        20062          9.1                    5
# ..         ...          ...                  ...
# 68      118605          7.9                    0
# 69      198482          7.5                    7
# 70      151229          5.5                    2
# 71      176140          6.0                    7
# 72      216879          4.1                    1
#
# [73 rows x 13 columns]

# %%
# Establish connection 

connection_string = "postgres:PW@localhost:5432/Game-of-Thrones"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Print table names
engine.table_names()

# Load data
got_battles.to_sql(name="kings_df", con=engine, if_exists='append', index=False)
got_scripts_name.to_sql(name="got_scripts_name", con=engine, if_exists='append', index=False)
got_ratings_df.to_sql(name="got_ratings_df", con=engine, if_exists='append', index=False)



# Read data using Pandas
pd.read_sql_query('select * from kings_df', con=engine)
pd.read_sql_query('select * from got_scripts_name', con=engine)
pd.read_sql_query('select * from got_ratings_df', con=engine)
# Out:
#     season  episode_number  number_in_season  \
# 0        1               1                 1
# 1        1               2                 2
# 2        1               3                 3
# 3        1               4                 4
# 4        1               5                 5
# ..     ...             ...               ...
# 68       8              69                 2
# 69       8              70                 3
# 70       8              71                 4
# 71       8              72                 5
# 72       8              73                 6
#
#                              episode_name                     director  \
# 0                        Winter Is Coming               Tim Van Patten
# 1                           The Kingsroad               Tim Van Patten
# 2                               Lord Snow                   Brian Kirk
# 3   Cripples, Bastards, and Broken Things                   Brian Kirk
# 4                   The Wolf and the Lion                   Brian Kirk
# ..                                    ...                          ...
# 68         A Knight of the Seven Kingdoms                 David Nutter
# 69                         The Long Night             Miguel Sapochnik
# 70                 The Last of the Starks                 David Nutter
# 71                              The Bells             Miguel Sapochnik
# 72                        The Iron Throne  David Benioff & D. B. Weiss
#
#                          writer original_air_date  us_viewers_millions  \
# 0   David Benioff & D. B. Weiss    April 17, 2011                 2.22
# 1   David Benioff & D. B. Weiss    April 24, 2011                 2.20
# 2   David Benioff & D. B. Weiss       May 1, 2011                 2.44
# 3                  Bryan Cogman       May 8, 2011                 2.45
# 4   David Benioff & D. B. Weiss      May 15, 2011                 2.58
# ..                          ...               ...                  ...
# 68                 Bryan Cogman    April 21, 2019                10.29
# 69  David Benioff & D. B. Weiss    April 28, 2019                12.02
# 70  David Benioff & D. B. Weiss       May 5, 2019                11.80
# 71  David Benioff & D. B. Weiss      May 12, 2019                12.40
# 72  David Benioff & D. B. Weiss      May 19, 2019                13.61
#
#     runtime_mins                                   imdb_description  \
# 0             62  Jon Arryn, the Hand of the King, is dead. King...
# 1             56  While Bran recovers from his fall, Ned takes o...
# 2             58  Lord Stark and his daughters arrive at King's ...
# 3             56  Eddard investigates Jon Arryn's murder. Jon be...
# 4             55  Catelyn has captured Tyrion and plans to bring...
# ..           ...                                                ...
# 68            58  Jaime faces judgment and Winterfell prepares f...
# 69            82  The Night King and his army have arrived at Wi...
# 70            78  The Battle of Winterfell is over and a new cha...
# 71            78  Forces have arrived at King's Landing for the ...
# 72            80  In the aftermath of the devastating attack on ...
#
#     imdb_votes  imdb_rating  notable_death_count
# 0        27685          9.0                    4
# 1        21256          8.8                    3
# 2        20090          8.7                    0
# 3        19123          8.8                    1
# 4        20062          9.1                    5
# ..         ...          ...                  ...
# 68      118605          7.9                    0
# 69      198482          7.5                    7
# 70      151229          5.5                    2
# 71      176140          6.0                    7
# 72      216879          4.1                    1
#
# [73 rows x 13 columns]

# %% [markdown]
# ### SQL Code
#
# ```sql
#
# DROP TABLE got_battles;
# DROP TABLE got_ratings;
# DROP TABLE got_scripts_name;
# DROP TABLE director_df
#
#
# CREATE TABLE got_ratings(
# 	season INT,
# 	episode_name VARCHAR,
# 	director VARCHAR,
# 	imdb_description VARCHAR,
# 	imdb_rating INT,
# 	notable_death_count INT
# );
#
# CREATE TABLE got_scripts_name(
#     name VARCHAR
# );
#
# CREATE TABLE director_df(
#     director VARCHAR(30),
#     imdb_rating VARCHAR(30)
# )
#
# SELECT * FROM got_battles
# SELECT * FROM got_ratings
# SELECT * FROM got_scripts_name
# SELECT * FROM director_df
#
#
#
#
#
# ```
